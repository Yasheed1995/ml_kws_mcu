# %%
from pydub import AudioSegment
from pydub.utils import make_chunks
import sys
import os
import subprocess

# %%
argv1 = "./44.1/"
chunk_length_ms = 1000

for subdir, dirs, files in os.walk(argv1):
    for file in files:
        #print os.path.join(subdir, file)
        filepath = subdir + os.sep + file

        if filepath.endswith(".wav"):
            print (filepath)
            myaudio = AudioSegment.from_file(filepath, "wav")
            chunks = make_chunks(myaudio, chunk_length_ms)
            for i, chunk in enumerate(chunks):
                chunk_name = os.path.abspath(os.path.join(filepath, os.pardir)) + os.sep + "chunk{0}.wav".format(i)
                print("exporting", chunk_name)
                chunk.export(chunk_name, format="wav")
# Out:
# ./44.1/chain/chunk103.wav
# exporting /Users/chenhongzhi/test/ML-KWS-for-MCU/wav_files/44.1/chain/chunk0.wav
# ./44.1/chain/chunk117.wav
# exporting /Users/chenhongzhi/test/ML-KWS-for-MCU/wav_files/44.1/chain/chunk0.wav
# ./44.1/chain/chunk2.wav
# exporting /Users/chenhongzhi/test/ML-KWS-for-MCU/wav_files/44.1/chain/chunk0.wav
# ./44.1/chain/chunk82.wav
# exporting /Users/chenhongzhi/test/ML-KWS-for-MCU/wav_files/44.1/chain/chunk0.wav
# ./44.1/chain/chunk96.wav
# exporting /Users/chenhongzhi/test/ML-KWS-for-MCU/wav_files/44.1/chain/chunk0.wav
# ./44.1/chain/chunk69.wav
# exporting /Users/chenhongzhi/test/ML-KWS-for-MCU/wav_files/44.1/chain/chunk0.wav
# ./44.1/chain/chunk41.wav
# exporting /Users/chenhongzhi/test/ML-KWS-for-MCU/wav_files/44.1/chain/chunk0.wav
# ./44.1/chain/chunk55.wav
# exporting /Users/chenhongzhi/test/ML-KWS-for-MCU/wav_files/44.1/chain/chunk0.wav
# ./44.1/chain/chunk54.wav
# exporting /Users/chenhongzhi/test/ML-KWS-for-MCU/wav_files/44.1/chain/chunk0.wav
# ...

# %%
for subdir, dirs, files in os.walk(argv1):
    for file in files:
        #print os.path.join(subdir, file)
        filepath = subdir + os.sep + file

        if filepath.endswith(".wav"):
            print(file)
# Out:
# chunk103.wav
# chunk117.wav
# chunk2.wav
# chunk82.wav
# chunk96.wav
# chunk69.wav
# chunk41.wav
# chunk55.wav
# chunk54.wav
# chunk40.wav
# chunk68.wav
# chunk97.wav
# chunk83.wav
# chunk3.wav
# chunk116.wav
# chunk102.wav
# chunk128.wav
# chunk114.wav
# chunk100.wav
# chunk1.wav
# chunk95.wav
# chunk81.wav
# chunk56.wav
# chunk42.wav
# chunk43.wav
# chunk57.wav
# chunk80.wav
# chunk94.wav
# chunk0.wav
# chunk101.wav
# chunk115.wav
# chunk129.wav
# chunk111.wav
# chunk105.wav
# chunk139.wav
# chunk4.wav
# chunk90.wav
# chunk84.wav
# chunk53.wav
# chunk47.wav
# chunk46.wav
# chunk52.wav
# chunk85.wav
# chunk91.wav
# chunk5.wav
# chunk138.wav
# chunk104.wav
# chunk110.wav
# chunk106.wav
# chunk112.wav
# chunk7.wav
# chunk87.wav
# chunk93.wav
# chunk44.wav
# chunk50.wav
# chunk78.wav
# chunk79.wav
# chunk51.wav
# chunk45.wav
# chunk92.wav
# chunk86.wav
# chunk6.wav
# chunk113.wav
# chunk107.wav
# chunk22.wav
# chunk36.wav
# chunk37.wav
# chunk23.wav
# chunk35.wav
# chunk21.wav
# ...
